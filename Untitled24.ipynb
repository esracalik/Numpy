# %%
import numpy as np

# %%
i=0
while i<201:
    if i%2==1:
         print(str(i)+" tek sayıdır")
    else:
         print(str(i)+" çift sayıdır")
    i+=1
np.ones((10,10))
# Out:
# 0 çift sayıdır
# 1 tek sayıdır
# 2 çift sayıdır
# 3 tek sayıdır
# 4 çift sayıdır
# 5 tek sayıdır
# 6 çift sayıdır
# 7 tek sayıdır
# 8 çift sayıdır
# 9 tek sayıdır
# 10 çift sayıdır
# 11 tek sayıdır
# 12 çift sayıdır
# 13 tek sayıdır
# 14 çift sayıdır
# 15 tek sayıdır
# 16 çift sayıdır
# 17 tek sayıdır
# 18 çift sayıdır
# 19 tek sayıdır
# 20 çift sayıdır
# 21 tek sayıdır
# 22 çift sayıdır
# 23 tek sayıdır
# 24 çift sayıdır
# 25 tek sayıdır
# 26 çift sayıdır
# 27 tek sayıdır
# 28 çift sayıdır
# 29 tek sayıdır
# 30 çift sayıdır
# 31 tek sayıdır
# 32 çift sayıdır
# 33 tek sayıdır
# 34 çift sayıdır
# 35 tek sayıdır
# 36 çift sayıdır
# 37 tek sayıdır
# 38 çift sayıdır
# 39 tek sayıdır
# 40 çift sayıdır
# 41 tek sayıdır
# 42 çift sayıdır
# 43 tek sayıdır
# 44 çift sayıdır
# 45 tek sayıdır
# 46 çift sayıdır
# 47 tek sayıdır
# 48 çift sayıdır
# 49 tek sayıdır
# 50 çift sayıdır
# 51 tek sayıdır
# 52 çift sayıdır
# 53 tek sayıdır
# 54 çift sayıdır
# 55 tek sayıdır
# 56 çift sayıdır
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3871f7fd1b3c> in <module>
# ----> 1 np.ones((3,4))
#
# NameError: name 'np' is not defined
